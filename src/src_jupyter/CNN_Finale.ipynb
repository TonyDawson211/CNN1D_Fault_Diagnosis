# %%
from src.CNN_Test import Test
from src.CNN_Model_Device import model
from src.CNN_Training_Data_Load import test_loader

te_acc_avr, best_tr_acc_avr, best_tr_state, tl, ta, vl, va = Test(model, test_loader)
# Out:
# epoch 01 | train loss 0.6405 | train acc 0.7148 | val loss 0.4371 | val acc 0.8179 |
# epoch 02 | train loss 0.3592 | train acc 0.8604 | val loss 0.3090 | val acc 0.8934 |
# epoch 03 | train loss 0.2415 | train acc 0.9114 | val loss 0.2354 | val acc 0.9147 |
# epoch 04 | train loss 0.1604 | train acc 0.9453 | val loss 0.1995 | val acc 0.9121 |
# epoch 05 | train loss 0.1117 | train acc 0.9606 | val loss 0.1901 | val acc 0.9272 |
# epoch 06 | train loss 0.0840 | train acc 0.9701 | val loss 0.1930 | val acc 0.9272 |
# epoch 07 | train loss 0.0695 | train acc 0.9779 | val loss 0.2096 | val acc 0.9263 |
# epoch 08 | train loss 0.0497 | train acc 0.9832 | val loss 0.1863 | val acc 0.9307 |
# epoch 09 | train loss 0.0410 | train acc 0.9869 | val loss 0.2163 | val acc 0.9254 |
# epoch 10 | train loss 0.0415 | train acc 0.9852 | val loss 0.2282 | val acc 0.9307 |
