# %%
import torch
from src.data_prerequisite.CNN_Training_Data_Load import train_loader
from src.model_structure_and_train_test.model_structure.CNN_Fusion_1D import model

# %%
x_cpu, y_cpu = next(iter(train_loader))  # 先看下数据格式，数据数字类型

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
x, y = x_cpu.to(device), y_cpu.to(device)

# %%
logits = model(x)  # 往前传播一次

# %%
# 计算迭代一次的损失
criterion = torch.nn.CrossEntropyLoss()
loss = criterion(logits, y)
